# %%
class fixNum:
  def __init__(self, a, b):
    self.a = int(a)
    self.b = int(b)

def addFixNum(a1, b1, a2, b2):
    x=fixNum(a1, b1)
    y=fixNum(a2, b2)
    result = fixNum(x.a+y.a, x.b+y.b)
    return(fixToFloat(result.a, result.b))

def fixNumPower(a1, b1, n):
    x=fixNum(a1, b1)
    result = fixNum(x.a**n, x.b**n)
    return(fixToFloat(result.a, result.b))

def fixToString(a, b):
    return({a}.{b:0{prec}d})

def Menu():
    while True:
        print("Menu:\n [a] Fixed-point addition \n [b] Fixed-poin`t multiplication \n [x] Exit") # Display a menu and handle user input
        choice = input("Enter your choice: ")
        if choice == 'a':
            print("Fixed point addition selected")
            a1 = input("Enter integral part of first number: ")
            b1 = input("Enter fractional part of first number: ")
            a2 = input("Enter integral part of second number: ")
            b2 = input("Enter fractional part of second number: ")
            print(addFixNum(a1, b1, a2, b2))
        elif choice == 'b':
            print("Fixed point nth power operation selected")
            a1 = input("Enter integral part of number: ")
            b1 = input("Enter fractional part of number: ")
            n = input("Enter the power n: ")
            print(fixNumPower(a1, b1, n))
        elif choice == 'x':
            print("Exiting the menu.")
            break
        else:
            print("Invalid choice. Please try again.")

Menu()
# Out:
# Menu:
#  [a] Fixed-point addition
#  [b] Fixed-poin`t multiplication
#  [x] Exit
# Fixed point nth power operation selected
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 44
#      41         else:
#      42             print("Invalid choice. Please try again.")
# ---> 44 Menu()
#
# Cell In[1], line 37, in Menu()
#      35     b1 = input("Enter fractional part of number: ")
#      36     n = input("Enter the power n: ")
# ---> 37     print(fixNumPower(a1, b1, n))
#      38 elif choice == 'x':
#      39     print("Exiting the menu.")
#
# Cell In[1], line 14, in fixNumPower(a1, b1, n)
#      12 def fixNumPower(a1, b1, n):
#      13     x=fixNum(a1, b1)
# ---> 14     result = fixNum(x.a**n, x.b**n)
#      15     return(fixToFloat(result.a, result.b))
#
# TypeError: unsupported operand type(s) for ** or pow(): 'int' and 'str'

# %%
class fixNum:
  def __init__(self, a, b):
    self.a = int(a)
    self.b = int(b)

  @classmethod
  def fixNumPower(cls, a1, b1, n):
    x=cls(a1, b1)
    result = cls(x.a**n, x.b**n)
    return()
  
def fixNumPower(a1, b1, n):
    x=fixNum(a1, b1)
    result = fixNum(x.a*n, x.b*n)
    print(x.a*n)
    print(x.b*n)
    return(fixToFloat(result.a, result.b))

a1 = input("Enter integral part of number: ")
b1 = input("Enter fractional part of number: ")
n = input("Enter the power n: ")
print(fixNumPower(a1, b1, n))
# Out:
# 3
# 33333
# 3.33333
