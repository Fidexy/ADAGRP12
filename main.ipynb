# %%
from fixNum import FixNum

# %load_ext autoreload
# %autoreload 2

userinput = input("Number of decimal places (default 2): ")    
prec = int(userinput) if userinput else 2
print("1st fixed point number:")
x = FixNum(prec)
x.input()
print(x)
print("prec: ", x.prec)
print("2nd fixed point number:")
y = FixNum(prec)
y.input()
print(y)
# print(float(x)**float(y))
print("x+y", x+y)
print("x^y: ", round((float(x)**float(y)), prec))
print(float(x)**float(y))
# Out:
# 1st fixed point number:
# 0.1
# prec:  1
# 2nd fixed point number:
# -0.1
# 1.0 -1.0 0.0
# 0 0
# x+y 0.0
# x^y:  0.8
# 0.7943282347242815

# %%
from fixNum import FixNum

# %load_ext autoreload
# %autoreload 2

userinput = input("Number of decimal places (default 2): ")    
prec = int(userinput) if userinput else 2
def Menu():
    while True:
        print("Menu:\n [a] Fixed-point addition \n [b] Fixed-point power operation \n [x] Exit") # Display a menu and handle user input
        choice = input("Enter your choice: ")
        if choice == 'a':
            print("Fixed-point addition selected (x+y).")
            print("Input 1st fixed point number:")
            x = FixNum(prec)
            x.input()
            print(x)
            print("Input 2nd fixed point number:")
            y = FixNum(prec)
            y.input()
            print(y)
            print("x + y =", x + y)
        elif choice == 'b':
            print("Fixed-point power operation selected (x^y).")
            print("Input 1st fixed point number:")
            x = FixNum(prec)
            x.input()
            print(x)
            print("Input power:")
            y = FixNum(prec)
            y.input()
            print(y)
            print("x ^ y =", round((float(x) ** float(y)), prec))
        elif choice == 'x':
            print("Exiting the menu.")
            break
        else:
            print("Invalid choice. Please try again.")
Menu()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Menu:
#  [a] Fixed-point addition
#  [b] Fixed-point power operation
#  [x] Exit
# Fixed-point addition selected (x+y).
# Input 1st fixed point number:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 40
#      37         else:
#      38             print("Invalid choice. Please try again.")
# ---> 40 Menu()
#
# Cell In[2], line 16, in Menu()
#      14 print("Input 1st fixed point number:")
#      15 x = FixNum(prec)
# ---> 16 x.input()
#      17 print(x)
#      18 print("Input 2nd fixed point number:")
#
# File ~/Documents/projpy/ADAGRP12/fixNum.py:12, in FixNum.input(self)
#      10 self.a, self.b = input(f"Enter number a.b as [a] [b] (precision {self.prec}): ").split()
#      11 if int(self.a) != 0 and int(self.b) < 0:
# ---> 12     raise Exception("Error: Negative fractional part with non-zero integral part.")
#      13 if len(str(abs(int(self.b)))) > self.prec:
#      14     raise Exception(f"Error: Fractional part exceeds precision of {self.prec} digits.")
#
# Exception: Error: Negative fractional part with non-zero integral part.
